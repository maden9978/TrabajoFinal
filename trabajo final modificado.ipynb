# %%
### LIBRERIAS
from selenium import webdriver #Después de haber instalado selenium
from selenium.webdriver.support.ui import WebDriverWait #Librería para esperar tiempo para dar click
from selenium.webdriver.support import expected_conditions as EC #Librerías para navegación y extraccion de información
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import time #Librería para pausar los códigos y darle tiempo a las páginas a que terminen de cargar
import pandas as pd #Con esta librería se hará dataframe de la información recopilada para su futuro envío por correo

# %%
### PRODUCTO A BUSCAR
producto = input("Ingrese el producto a buscar: ")
# Out:
# Ingrese el producto a buscar: Arroz

# %%
### METRO
# Opciones de navegación
options =  webdriver.ChromeOptions()
options.add_argument('--start-maximized')
options.add_argument('--disable-extensions')
driver = webdriver.Chrome(options=options)
time.sleep(1)

# Inicializamos el navegador
driver.get("https://www.metro.pe/")


# Clicks para cerrar opciones de cookies en la pagina
WebDriverWait(driver, 20)\
    .until(EC.element_to_be_clickable((By.XPATH,"//button[@class='align-right secondary slidedown-button']")))\
    .click()

WebDriverWait(driver, 15)\
    .until(EC.element_to_be_clickable((By.XPATH,"//button[@class='swal2-confirm swal2-styled']")))\
    .click()

#Click para ingresar producto a buscar
WebDriverWait(driver, 5)\
    .until(EC.element_to_be_clickable((By.XPATH,"//input[@id='search-autocomplete-input']")))\
    .send_keys(producto)

#Click para buscar todos los productos
WebDriverWait(driver, 15)\
    .until(EC.element_to_be_clickable((By.XPATH,"//a[@class='see-all']")))\
    .click()

#Mover la barra vertical de desplazamiento hacia abajo para cargar todos los productos
driver.execute_script("window.scrollBy(0, document.body.scrollHeight);")

#le damos tiempo al a que carguen todos los productos
time.sleep(15)

# Definiendo nombres y precios

def precios_metro():
    tarifas = driver.find_elements(By.XPATH,"//div[@class='product-item__bottom']") #Asignando espacio donde se encuentra la información a recopilar
    precios = [] #Creando lista de precios
    nombres = [] #Creando listas de nombres 
    for tarifa in tarifas: #Recorriendo tarifas
        nombre = tarifa.find_element(By.XPATH,".//a[@class='product-item__name']").text #Extrayendo texto de los nombres
        precio = tarifa.find_element(By.XPATH,".//span[@class='product-prices__value product-prices__value--best-price']").text #Extrayendo texto de los precios
        nombres.append(nombre) #Agregando a listas
        precios.append(precio)
    df_metro=pd.DataFrame({"Nombre_producto":nombres,"Precios_en_soles":precios, "Supermercado":["metro"]*len(nombres)}) #Creando DataFrame
    return df_metro
precios_metro()
# Out:
#                            Nombre_producto Precios_en_soles Supermercado
# 0                  Arroz Extra Costeño 5kg        S/. 23.45        metro
# 1                 Arroz Saman Costal 50 Kg       S/. 192.50        metro
# 2               Arroz Superior Bolsa 10 Kg        S/. 34.60        metro
# 3              Harina de Arroz Costeño 1 g           S/6.59        metro
# 4            Arroz Extra Metro Bolsa 750 g         S/. 3.20        metro
# ..                                     ...              ...          ...
# 92           Garbanzos Costeño Bolsa 500 g           S/6.00        metro
# 93    Arveja Verde Valle Norte Bolsa 500 g           S/4.29        metro
# 94  Frijol Canario Valle Norte Bolsa 500 g           S/7.99        metro
# 95         Lenteja Valle Norte Bolsa 500 g           S/5.79        metro
# 96   Maíz Pop Corn Valle Norte Bolsa 500 g           S/5.29        metro
#
# [97 rows x 3 columns]

# %%
### TOTTUS
# Opciones de navegación
options =  webdriver.ChromeOptions()
options.add_argument('--start-maximized')
options.add_argument('--disable-extensions')
driver = webdriver.Chrome(options=options)
time.sleep(1)

# Inicializamos el driver
driver.get("https://www.tottus.com.pe/")

 
# Click para cerrar opciones de cookies en la pagina
WebDriverWait(driver, 40)\
    .until(EC.element_to_be_clickable((By.XPATH,"//button[@class='align-right secondary slidedown-button']")))\
    .click()

#Click para ingresar producto a buscar
WebDriverWait(driver, 10)\
    .until(EC.element_to_be_clickable((By.XPATH,"//input[@class='jsx-3290144217 desktopSearchBar']")))\
    .send_keys(producto)

#Click para buscar todos los productos
WebDriverWait(driver, 10)\
    .until(EC.element_to_be_clickable((By.XPATH,"//button[@class='jsx-3290144217 searchIcon']")))\
    .click()

#Le damos 10 segundos para que cargue
time.sleep(10)

def precios_tottus():
    casillas = driver.find_elements(By.XPATH,"//li[@class='product']")
    precios = []
    nombres = []
    for casilla in casillas:
        nombre = casilla.find_element(By.XPATH,".//h2[@class='jsx-369422875 name title mini']").text
        precio = casilla.find_element(By.XPATH,".//div[@class='jsx-4019956066 ProductPrice']").text
        nombres.append(nombre)
        precios.append(precio)
        df_tottus=pd.DataFrame({"Nombre_producto":nombres,"Precios_en_soles":precios, "Supermercado":["tottus"]*len(nombres)})
    return df_tottus
precios_tottus()
# Out:
#                                Nombre_producto  \
# 0                   ARROZ INTEGRAL TOTTUS 5 KG
# 1      ARROZ EXTRA AÑEJO TOTTUS PREMIUM 750 GR
# 2           ARROZ EXTRA INTEGRAL TOTTUS 750 GR
# 3                  ARROZ SUPERIOR TOTTUS 10 KG
# 4                    ARROZ EXTRA TOTTUS 750 GR
# 5                   ARROZ SUPERIOR TOTTUS 5 KG
# 6                     ARROZ EXTRA TOTTUS 10 KG
# 7                      ARROZ EXTRA TOTTUS 5 KG
# 8                 ARROZ SUPERIOR TOTTUS 750 GR
# 9         VERDURAS PARA ARROZ CON POLLO TOTTUS
# 10                              ARROZ SUPERIOR
# 11                              ARROZ SUPERIOR
# 12                     ARROZ EXTRA FARAON 5 KG
# 13                       ARROZ PRECIO UNO 5 KG
# 14                   ARROZ EXTRA FARAÓN 750 GR
# 15                          ARROZ ARBORIO 1 KG
# 16                       ARROZ SUPERIOR 750 GR
# 17                     ARROZ PRECIO UNO 750 GR
# 18                  ARROZ EXTRA NATURAL 750 GR
# 19                      ARROZ SUPERIOR COSTEÑO
# 20                                 ARROZ EXTRA
# 21                            ARROZ EXTRA 1 KG
# 22                    ARROZ EXTRA COSTEÑO 5 KG
# 23                  ARROZ EXTRA COSTEÑO 750 GR
# 24                              ARROZ INTEGRAL
# 25              ARROZ SUPERIOR VALLENORTE 5 KG
# 26              ARROZ PARBOLIZADO PAISANA 1 KG
# 27            ARROZ SUPERIOR VALLENORTE 750 GR
# 28               ARROZ INTEGRAL COSTEÑO 750 GR
# 29                 ARROZ BASMATI SCOTTI 500 GR
# 30                       ARROZ SUPERIOR 750 GR
# 31                      ARROZ GRAN NERO 500 GR
# 32                 ARROZ SUPERIOR PAISANA 1 KG
# 33                 ARROZ SUPERIOR COSTEÑO 5 KG
# 34               ARROZ EXTRA GRAN CHALAN X 5KG
# 35                ARROZ ARBORIO COSTEÑO 750 GR
# 36             ARROZ PARBOLIZADO COTEÑO 750 GR
# 37                 ARROZ SUPERIOR PAISANA 5 KG
# 38                       KIT PAELLA 4 RACIONES
# 39  ARROZ GOURMET EXTRA AÑEJO GRAN CHALAN 5 KG
# 40                 ARROZ EXTRA VALLENORTE 5 KG
# 41               ARROZ EXTRA VALLENORTE 750 GR
# 42  ARROZ ESPECIAL PARA PAELLA EL AVIÓN 500 GR
# 43                   BEBIDA DE ARROZ ORASI 1LT
# 44     SAZONADOR DE ARROZ DELIARROZ 6 UNIDADES
# 45               KIT DE PAELLA EL AVIÓN PARA 6
# 46    FETUCCINI ARROZ Y YUCA SIN GLUTEN 400 GR
# 47      GALLETAS DE ARROZ DULCE COSTEÑO 150 GR
#
#                       Precios_en_soles Supermercado
# 0                           s/ 20.9 UN       tottus
# 1                            s/ 3.9 UN       tottus
# 2                            s/ 3.7 UN       tottus
# 3               s/ 31.9 UN\ns/ 34.6 UN       tottus
# 4                            s/ 3.5 UN       tottus
# 5               s/ 16.3 UN\ns/ 18.6 UN       tottus
# 6               s/ 32.9 UN\ns/ 36.3 UN       tottus
# 7   s/ 16.5 UN\ns/ 16.9 UN\ns/ 19.7 UN       tottus
# 8                            s/ 3.1 UN       tottus
# 9                            s/ 7.5 UN       tottus
# 10                          s/ 25.6 UN       tottus
# 11                          s/ 21.3 UN       tottus
# 12                         s/ 27.95 UN       tottus
# 13              s/ 15.7 UN\ns/ 16.5 UN       tottus
# 14                           s/ 4.6 UN       tottus
# 15                          s/ 40.9 UN       tottus
# 16                           s/ 3.7 UN       tottus
# 17                           s/ 2.8 UN       tottus
# 18                           s/ 3.9 UN       tottus
# 19                           s/ 4.3 UN       tottus
# 20                          s/ 18.9 UN       tottus
# 21                             s/ 5 UN       tottus
# 22                          s/ 22.5 UN       tottus
# 23                           s/ 4.8 UN       tottus
# 24                           s/ 7.7 UN       tottus
# 25                          s/ 20.6 UN       tottus
# 26                           s/ 6.6 UN       tottus
# 27                           s/ 3.8 UN       tottus
# 28                           s/ 6.7 UN       tottus
# 29                          s/ 24.1 UN       tottus
# 30                           s/ 4.1 UN       tottus
# 31                          s/ 26.9 UN       tottus
# 32                             s/ 5 UN       tottus
# 33                          s/ 20.6 UN       tottus
# 34                          s/ 21.8 UN       tottus
# 35                          s/ 10.2 UN       tottus
# 36                           s/ 5.5 UN       tottus
# 37                          s/ 18.7 UN       tottus
# 38                          s/ 79.9 UN       tottus
# 39                          s/ 22.8 UN       tottus
# 40                          s/ 26.4 UN       tottus
# 41                          s/ 4.25 UN       tottus
# 42                          s/ 11.5 UN       tottus
# 43                          s/ 17.6 UN       tottus
# 44                           s/ 1.9 UN       tottus
# 45                          s/ 99.9 UN       tottus
# 46                         s/ 20.75 UN       tottus
# 47                           s/ 6.9 UN       tottus

# %%
### PLAZA VEA

# Opciones de navegación
options =  webdriver.ChromeOptions()
options.add_argument('--start-maximized')
options.add_argument('--disable-extensions')
driver = webdriver.Chrome(options=options)
time.sleep(1)

# Inicializamos el driver
driver.get("https://www.plazavea.com.pe/")

# Click para cerrar opciones de cookies en la pagina
WebDriverWait(driver, 25)\
    .until(EC.element_to_be_clickable((By.XPATH,"//button[@class='align-right secondary slidedown-button']")))\
    .click()

#Click para ingresar producto a buscar
WebDriverWait(driver, 10)\
    .until(EC.element_to_be_clickable((By.XPATH,"//input[@id='search_box']")))\
    .send_keys(producto)

#Click para buscar todos los productos
WebDriverWait(driver, 15)\
    .until(EC.element_to_be_clickable((By.XPATH,"//a[@class='SuggestionList__searchLink__link']")))\
    .click()

#Le damos segundos para que cargue la página
time.sleep(15)


def precios_pv():
    casillas = driver.find_elements(By.XPATH,"//div[@class ='Showcase__details']")
    precios = []
    nombres = []
    for casilla in casillas:
        nombre = casilla.find_element(By.XPATH,".//a[@class='Showcase__name']").text
        precio = casilla.find_element(By.XPATH,".//span[@class='price']").text
        nombres.append(nombre)
        precios.append(precio)
        df_plazavea=pd.DataFrame({"Nombre_producto":nombres,"Precios_en_soles":precios, "Supermercado":["plazavea"]*len(nombres)})
    return df_plazavea
precios_pv()
# Out:
#                                       Nombre_producto Precios_en_soles  \
# 0          Arroz Extra Añejo FARAON Naranja Bolsa 5kg      S/ 23.59 un
# 1                    Arroz Superior PAISANA Bolsa 5Kg      S/ 19.50 un
# 2                       Arroz Extra COSTEÑO Bolsa 5Kg      S/ 23.50 un
# 3                       Arroz Extra PAISANA Bolsa 5Kg      S/ 16.50 un
# 4                        Arroz Extra BELL'S Bolsa 5Kg      S/ 16.70 un
# 5       Arroz Extra VALLENORTE Gran Reserva Bolsa 5Kg      S/ 20.90 un
# 6                   Arroz Extra GRAN CHALAN Bolsa 5Kg      S/ 18.90 un
# 7            Arroz FARAON Añejo Amarillo G3 Bolsa 5kg      S/ 18.90 un
# 8                     Arroz Superior BELL'S Bolsa 5Kg      S/ 15.70 un
# 9                      Arroz Extra COSTEÑO Bolsa 750g       S/ 4.20 un
# 10     Arroz Extra VALLENORTE Gran Reserva Bolsa 750g       S/ 3.89 un
# 11               Arroz Integral VALLENORTE Bolsa 750g       S/ 4.40 un
# 12                    Arroz Integral BELL'S Bolsa 5Kg      S/ 19.20 un
# 13                  Arroz Extra FARAON Azul Bolsa 5kg      S/ 21.90 un
# 14               Arroz Superior GRAN CHALAN Bolsa 5Kg         S/ 18 un
# 15                      Arroz Extra FARAON Bolsa 750g       S/ 3.79 un
# 16                Arroz Superior VALLENORTE Bolsa 5Kg      S/ 20.60 un
# 17                  Arroz Superior COSTEÑO Bolsa 750g       S/ 3.70 un
# 18                      Arroz Extra BELL'S Bolsa 750g       S/ 3.20 un
# 19                   Arroz Superior COSTEÑO Bolsa 5Kg      S/ 20.60 un
# 20                  Arroz Integral COSTEÑO Bolsa 750g       S/ 5.30 un
# 21                    Arroz BELL'S Familiar Bolsa 5Kg      S/ 14.50 un
# 22           Arroz Añejo Amarillo FARAÓN G3 Bolsa 1Kg       S/ 4.10 un
# 23                   Arroz Integral PAISANA Bolsa 1Kg       S/ 6.19 un
# 24               Arroz Superior VALLENORTE Bolsa 750g       S/ 3.19 un
# 25               Arroz Parbolizado COSTEÑO Bolsa 750g       S/ 4.70 un
# 26                   Arroz BELL'S Familiar Bolsa 750g       S/ 2.80 un
# 27           Arroz Integral Riso INCATRAIL Bolsa 500g       S/ 3.89 un
# 28                   Arroz Superior PAISANA Bolsa 1Kg       S/ 4.50 un
# 29                   Arroz Superior BELL'S Bolsa 750g       S/ 3.10 un
# 30                   Arroz Arborio COSTEÑO Bolsa 750g       S/ 8.80 un
# 31                Arroz con Pollo BELL'S Bandeja 200g       S/ 7.80 un
# 32                     Arroz Basmati SCOTTI Caja 500g      S/ 14.69 un
# 33              Arroz Superior GRAN CHALAN Bolsa 750g       S/ 3.40 un
# 34              Arroz con Mariscos ODISSEA Bolsa 500g      S/ 25.90 un
# 35            Arroz Extra BELL'S Selección Bolsa 750g       S/ 3.50 un
# 36       Arroz Carnaroli SCOTTI con Trufas Bolsa 210g      S/ 12.69 un
# 37                 Arroz Extra GRAN CHALAN Bolsa 750g       S/ 3.60 un
# 38  Jabón & Mascarilla BIOCLEAN Caléndula + Arroz ...      S/ 10.90 un
# 39  Pack Cuchara para Arroz Modelo Osito + Prensad...      S/ 19.99 un
# 40         Arroz para Cocina Oriental Mizu Bolsa 5 kg         S/ 28 un
# 41         Arroz para Cocina Oriental Mizu Bolsa 1 kg       S/ 6.50 un
# 42         Cuchara Paleta para Arroz Diseño Oso Beige      S/ 16.06 un
# 43          Cuchara Paleta para Arroz Diseño Oso Rosa      S/ 16.06 un
# 44       Licor de Arroz TOKUBETSU Kaiun Botella 700ml      S/ 89.90 un
# 45  Arroz Carnaroli SCOTTI Funghi Porcin Bolsa 210...      S/ 12.69 un
# 46             Arroz Sushi SCOTTI Hakunami Bolsa 500g      S/ 12.99 un
# 47             Arroz Andino Riso INCATRAIL Bolsa 500g          S/ 6 un
# 48                    Arroz Orgánico SCOTTI Caja 500g      S/ 12.59 un
# 49                      Arroz Arborio SCOTTI Caja 1Kg      S/ 24.79 un
#
#    Supermercado
# 0      plazavea
# 1      plazavea
# 2      plazavea
# 3      plazavea
# 4      plazavea
# 5      plazavea
# 6      plazavea
# 7      plazavea
# 8      plazavea
# 9      plazavea
# 10     plazavea
# 11     plazavea
# 12     plazavea
# 13     plazavea
# 14     plazavea
# 15     plazavea
# 16     plazavea
# 17     plazavea
# 18     plazavea
# 19     plazavea
# 20     plazavea
# 21     plazavea
# 22     plazavea
# 23     plazavea
# 24     plazavea
# 25     plazavea
# 26     plazavea
# 27     plazavea
# 28     plazavea
# 29     plazavea
# 30     plazavea
# 31     plazavea
# 32     plazavea
# 33     plazavea
# 34     plazavea
# 35     plazavea
# 36     plazavea
# 37     plazavea
# 38     plazavea
# 39     plazavea
# 40     plazavea
# 41     plazavea
# 42     plazavea
# 43     plazavea
# 44     plazavea
# 45     plazavea
# 46     plazavea
# 47     plazavea
# 48     plazavea
# 49     plazavea

# %%
### LIBRERÍAS Y CÓDIGOS PARA PRÓXIMO ENVÍO DE INFORMACIÓN POR CORREO

# %%
pip install imghdr

# %%
import imghdr #Librería para enviar archivos por correo
import smtplib #Librería para enviar correos desde Python
import ssl #Esta librería brinda mayor seguridad para trabajar con los correos
from email.message import EmailMessage #Con esta librería definimos el código para el emisor y receptor

# Define email mensajero y receptor
email_sender = input("escriba su correo: ")
email_password = input("contraseña: ")
email_receiver = input("correo receptor: ")

# Configurar el asunto y cuerpo de texto
subject = 'Precios'
body = """En este correo se le envía en formato csv a usted los precios de los tres supermercados a analizar
.
.
.
"""
#Definiendo parámetros de envío 
em = EmailMessage()
em['From'] = email_sender
em['To'] = email_receiver
em['Subject'] = subject
em.set_content(body)

# Adjuntar archivo
wit open('precios.csv','rb') as file:  #Agregando futuro archivo csv donde se compararan los precios"
    file_data = file.read() #Informacion del archivo
    file_tipo = imghdr.what(file.name) #Tipo de archivo
    filer_nombre = file.name #Nombre del archivo
em.add_attachment(file_data, filename=file_nombre, subtype = file_tipo, maintype = "application") #Parámetros del archivo adjunto para su futuro envío

# Añadiendo SSL para mayor seguridad de navegación
context = ssl.create_default_context()

# Codigo para logear y mandar el email
with smtplib.SMTP_SSL('smtp.gmail.com', 465, context=context) as smtp: #Se define parámetros para el envío
    smtp.login(email_sender, email_password)
    smtp.sendmail(email_sender, email_receiver, em.as_string())
